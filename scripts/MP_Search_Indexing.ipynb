# %%
import pandas as pd

prefix = "http://mousephenotype.org/ontology#"

curie_map = dict()
curie_map['impc']=prefix
curie_map['MP']='http://purl.obolibrary.org/obo/MP_'
curie_map['HP']='http://purl.obolibrary.org/obo/HP_'
curie_map['oio']='http://www.geneontology.org/formats/oboInOwl#'
curie_map['rdfs']='http://www.w3.org/2000/01/rdf-schema#'

# %%
df_mp_l = pd.read_csv('tables/mp_lexical.csv')
df_hp_l = pd.read_csv('tables/hp_lexical.csv')
df_mp_p = pd.read_csv('tables/mp_parentage.csv')
df_mp_hp = pd.read_csv('tables/mp_hp_matches.csv')
df_mp_l['property']
# Out:
# 0               http://www.w3.org/2000/01/rdf-schema#label
# 1               http://www.w3.org/2000/01/rdf-schema#label
# 2               http://www.w3.org/2000/01/rdf-schema#label
# 3               http://www.w3.org/2000/01/rdf-schema#label
# 4               http://www.w3.org/2000/01/rdf-schema#label
# 5               http://www.w3.org/2000/01/rdf-schema#label
# 6               http://www.w3.org/2000/01/rdf-schema#label
# 7               http://www.w3.org/2000/01/rdf-schema#label
# 8               http://www.w3.org/2000/01/rdf-schema#label
# 9               http://www.w3.org/2000/01/rdf-schema#label
# 10              http://www.w3.org/2000/01/rdf-schema#label
# 11              http://www.w3.org/2000/01/rdf-schema#label
# 12              http://www.w3.org/2000/01/rdf-schema#label
# 13              http://www.w3.org/2000/01/rdf-schema#label
# 14              http://www.w3.org/2000/01/rdf-schema#label
# 15              http://www.w3.org/2000/01/rdf-schema#label
# 16              http://www.w3.org/2000/01/rdf-schema#label
# 17              http://www.w3.org/2000/01/rdf-schema#label
# 18              http://www.w3.org/2000/01/rdf-schema#label
# 19              http://www.w3.org/2000/01/rdf-schema#label
# 20              http://www.w3.org/2000/01/rdf-schema#label
# 21              http://www.w3.org/2000/01/rdf-schema#label
# 22              http://www.w3.org/2000/01/rdf-schema#label
# 23              http://www.w3.org/2000/01/rdf-schema#label
# 24              http://www.w3.org/2000/01/rdf-schema#label
# 25              http://www.w3.org/2000/01/rdf-schema#label
# 26              http://www.w3.org/2000/01/rdf-schema#label
# 27              http://www.w3.org/2000/01/rdf-schema#label
# 28              http://www.w3.org/2000/01/rdf-schema#label
# 29              http://www.w3.org/2000/01/rdf-schema#label
#                                ...
# 37111    http://www.geneontology.org/formats/oboInOwl#h...
# 37112    http://www.geneontology.org/formats/oboInOwl#h...
# 37113    http://www.geneontology.org/formats/oboInOwl#h...
# 37114    http://www.geneontology.org/formats/oboInOwl#h...
# 37115    http://www.geneontology.org/formats/oboInOwl#h...
# 37116    http://www.geneontology.org/formats/oboInOwl#h...
# 37117    http://www.geneontology.org/formats/oboInOwl#h...
# 37118    http://www.geneontology.org/formats/oboInOwl#h...
# 37119    http://www.geneontology.org/formats/oboInOwl#h...
# 37120    http://www.geneontology.org/formats/oboInOwl#h...
# 37121    http://www.geneontology.org/formats/oboInOwl#h...
# 37122    http://www.geneontology.org/formats/oboInOwl#h...
# 37123    http://www.geneontology.org/formats/oboInOwl#h...
# 37124    http://www.geneontology.org/formats/oboInOwl#h...
# 37125    http://www.geneontology.org/formats/oboInOwl#h...
# 37126    http://www.geneontology.org/formats/oboInOwl#h...
# 37127    http://www.geneontology.org/formats/oboInOwl#h...
# 37128    http://www.geneontology.org/formats/oboInOwl#h...
# 37129    http://www.geneontology.org/formats/oboInOwl#h...
# 37130    http://www.geneontology.org/formats/oboInOwl#h...
# 37131    http://www.geneontology.org/formats/oboInOwl#h...
# 37132    http://www.geneontology.org/formats/oboInOwl#h...
# 37133    http://www.geneontology.org/formats/oboInOwl#h...
# 37134    http://www.geneontology.org/formats/oboInOwl#h...
# 37135    http://www.geneontology.org/formats/oboInOwl#h...
# 37136    http://www.geneontology.org/formats/oboInOwl#h...
# 37137    http://www.geneontology.org/formats/oboInOwl#h...
# 37138    http://www.geneontology.org/formats/oboInOwl#h...
# 37139    http://www.geneontology.org/formats/oboInOwl#h...
# 37140    http://www.geneontology.org/formats/oboInOwl#h...
# Name: property, Length: 37141, dtype: object

# %%
df_mp_l.head()
# Out:
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0005370
# 2  http://purl.obolibrary.org/obo/MP_0002139
# 3  http://purl.obolibrary.org/obo/MP_0000609
# 4  http://purl.obolibrary.org/obo/MP_0010080
#
#                                      property  \
# 0  http://www.w3.org/2000/01/rdf-schema#label
# 1  http://www.w3.org/2000/01/rdf-schema#label
# 2  http://www.w3.org/2000/01/rdf-schema#label
# 3  http://www.w3.org/2000/01/rdf-schema#label
# 4  http://www.w3.org/2000/01/rdf-schema#label
#
#                                       value
# 0                       mammalian phenotype
# 1            liver/biliary system phenotype
# 2  abnormal hepatobiliary system physiology
# 3                 abnormal liver physiology
# 4            abnormal hepatocyte physiology

# %%
df_hp_l.head()
# Out:
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/HP_0000118
# 1  http://purl.obolibrary.org/obo/HP_0001939
# 2  http://purl.obolibrary.org/obo/HP_0012337
# 3  http://purl.obolibrary.org/obo/HP_0012338
# 4  http://purl.obolibrary.org/obo/HP_0012339
#
#                                      property  \
# 0  http://www.w3.org/2000/01/rdf-schema#label
# 1  http://www.w3.org/2000/01/rdf-schema#label
# 2  http://www.w3.org/2000/01/rdf-schema#label
# 3  http://www.w3.org/2000/01/rdf-schema#label
# 4  http://www.w3.org/2000/01/rdf-schema#label
#
#                                    value
# 0                 Phenotypic abnormality
# 1  Abnormality of metabolism/homeostasis
# 2                   Abnormal homeostasis
# 3            Abnormal energy expenditure
# 4   Increased resting energy expenditure

# %%
print(len(df_mp_p))
df_mp_p.columns = ['x','y']
df_mp_p=df_mp_p[df_mp_p['x']!=df_mp_p['y']]
print(len(df_mp_p))
df_mp_p.head()
# Out:
# 124924
# 111961
#                                            x  \
# 1  http://purl.obolibrary.org/obo/MP_0002006
# 2  http://purl.obolibrary.org/obo/MP_0002166
# 3  http://purl.obolibrary.org/obo/MP_0002009
# 4  http://purl.obolibrary.org/obo/MP_0002019
# 5  http://purl.obolibrary.org/obo/MP_0002052
#
#                                            y
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0000001
# 3  http://purl.obolibrary.org/obo/MP_0000001
# 4  http://purl.obolibrary.org/obo/MP_0000001
# 5  http://purl.obolibrary.org/obo/MP_0000001

# %%
df_mp_hp=df_mp_hp[['x','y']]
df_mp_hp.head()
# Out:
#                                            x  \
# 0  http://purl.obolibrary.org/obo/HP_0009124
# 1  http://purl.obolibrary.org/obo/HP_0008551
# 2  http://purl.obolibrary.org/obo/HP_0000411
# 3  http://purl.obolibrary.org/obo/HP_0000375
# 4  http://purl.obolibrary.org/obo/HP_0009910
#
#                                            y
# 0  http://purl.obolibrary.org/obo/MP_0000003
# 1  http://purl.obolibrary.org/obo/MP_0000018
# 2  http://purl.obolibrary.org/obo/MP_0000021
# 3  http://purl.obolibrary.org/obo/MP_0000031
# 4  http://purl.obolibrary.org/obo/MP_0000040

# %%
# Out:
#     phenotype    property                                     value
# 0  MP:0000001  rdfs:label                       mammalian phenotype
# 1  MP:0005370  rdfs:label            liver/biliary system phenotype
# 2  MP:0002139  rdfs:label  abnormal hepatobiliary system physiology
# 3  MP:0000609  rdfs:label                 abnormal liver physiology
# 4  MP:0010080  rdfs:label            abnormal hepatocyte physiology

# %%
def match_pre(df_hp_l,df_mp_hp,prop,prop_name):
    dfh = df_hp_l[df_hp_l['property']==prop]
    dfh = dfh.merge(right=df_mp_hp,left_on='phenotype', right_on='x', how='inner')
    df = dfh[['y','property','value']]
    df.columns = ['phenotype','property','value']
    df['property']=prefix+prop_name
    return df

# %%
dfhl = match_pre(df_hp_l,df_mp_hp,"http://www.w3.org/2000/01/rdf-schema#label","hpLabel")
dfhl.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0005266
# 1  http://purl.obolibrary.org/obo/MP_0001764
# 2  http://purl.obolibrary.org/obo/MP_0005534
# 3  http://purl.obolibrary.org/obo/MP_0001785
# 4  http://purl.obolibrary.org/obo/MP_0010334
#
#                                      property  \
# 0  http://mousephenotype.org/ontology#hpLabel
# 1  http://mousephenotype.org/ontology#hpLabel
# 2  http://mousephenotype.org/ontology#hpLabel
# 3  http://mousephenotype.org/ontology#hpLabel
# 4  http://mousephenotype.org/ontology#hpLabel
#
#                                    value
# 0  Abnormality of metabolism/homeostasis
# 1                   Abnormal homeostasis
# 2                            Hypothermia
# 3                                  Edema
# 4                       Pleural effusion

# %%
dfhs = match_pre(df_hp_l,df_mp_hp,"http://www.geneontology.org/formats/oboInOwl#hasExactSynonym","hpExactSynonym")
dfhs.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0005266
# 1  http://purl.obolibrary.org/obo/MP_0005266
# 2  http://purl.obolibrary.org/obo/MP_0005534
# 3  http://purl.obolibrary.org/obo/MP_0005534
# 4  http://purl.obolibrary.org/obo/MP_0001785
#
#                                             property  \
# 0  http://mousephenotype.org/ontology#hpExactSynonym
# 1  http://mousephenotype.org/ontology#hpExactSynonym
# 2  http://mousephenotype.org/ontology#hpExactSynonym
# 3  http://mousephenotype.org/ontology#hpExactSynonym
# 4  http://mousephenotype.org/ontology#hpExactSynonym
#
#                              value
# 0           Metabolism abnormality
# 1           Laboratory abnormality
# 2  Abnormally low body temperature
# 3                      Hypothermia
# 4                  Water retention

# %%
df_child1_s = match_pre(df_mp_l,df_mp_p,'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym',"childOneSynonym")
df_child1_s.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0005370
# 3  http://purl.obolibrary.org/obo/MP_0000001
# 4  http://purl.obolibrary.org/obo/MP_0005370
#
#                                             property  \
# 0  http://mousephenotype.org/ontology#childOneSyn...
# 1  http://mousephenotype.org/ontology#childOneSyn...
# 2  http://mousephenotype.org/ontology#childOneSyn...
# 3  http://mousephenotype.org/ontology#childOneSyn...
# 4  http://mousephenotype.org/ontology#childOneSyn...
#
#                                         value
# 0              hepatobiliary system phenotype
# 1  liver/hepatic system: functional anomalies
# 2  liver/hepatic system: functional anomalies
# 3    abnormal liver/biliary system physiology
# 4    abnormal liver/biliary system physiology

# %%
df_child1_l = match_pre(df_mp_l,df_mp_p,"http://www.w3.org/2000/01/rdf-schema#label","childOneLabel")
df_child1_l.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0005370
# 3  http://purl.obolibrary.org/obo/MP_0000001
# 4  http://purl.obolibrary.org/obo/MP_0005370
#
#                                            property  \
# 0  http://mousephenotype.org/ontology#childOneLabel
# 1  http://mousephenotype.org/ontology#childOneLabel
# 2  http://mousephenotype.org/ontology#childOneLabel
# 3  http://mousephenotype.org/ontology#childOneLabel
# 4  http://mousephenotype.org/ontology#childOneLabel
#
#                                       value
# 0            liver/biliary system phenotype
# 1  abnormal hepatobiliary system physiology
# 2  abnormal hepatobiliary system physiology
# 3                 abnormal liver physiology
# 4                 abnormal liver physiology

# %%
df_mp_c2 = df_mp_p.copy()
df_mp_c2.columns = ['sub','phenotype']
df_mp_c2 = df_mp_c2.merge(right=df_mp_p,left_on='sub', right_on='y', how='inner')
df_mp_c2=df_mp_c2[['phenotype','x']].drop_duplicates()
df_mp_c2.columns = ['y','x']
df_mp_c2.head()
# Out:
#                                            y  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0000001
# 3  http://purl.obolibrary.org/obo/MP_0000001
# 4  http://purl.obolibrary.org/obo/MP_0000001
#
#                                            x
# 0  http://purl.obolibrary.org/obo/MP_0002166
# 1  http://purl.obolibrary.org/obo/MP_0002009
# 2  http://purl.obolibrary.org/obo/MP_0002019
# 3  http://purl.obolibrary.org/obo/MP_0002052
# 4  http://purl.obolibrary.org/obo/MP_0010282

# %%
df_child2_s = match_pre(df_mp_l,df_mp_c2,'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym',"childTwoSynonym")
df_child2_s.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0000001
# 3  http://purl.obolibrary.org/obo/MP_0005370
# 4  http://purl.obolibrary.org/obo/MP_0000001
#
#                                             property  \
# 0  http://mousephenotype.org/ontology#childTwoSyn...
# 1  http://mousephenotype.org/ontology#childTwoSyn...
# 2  http://mousephenotype.org/ontology#childTwoSyn...
# 3  http://mousephenotype.org/ontology#childTwoSyn...
# 4  http://mousephenotype.org/ontology#childTwoSyn...
#
#                                         value
# 0  liver/hepatic system: functional anomalies
# 1    abnormal liver/biliary system physiology
# 2                   abnormal hepatic function
# 3                   abnormal hepatic function
# 4                     abnormal liver function

# %%
df_child2_l = match_pre(df_mp_l,df_mp_c2,'http://www.w3.org/2000/01/rdf-schema#label',"childTwoLabel")
df_child2_l.head()
# Out:
# /Users/matentzn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0000001
# 2  http://purl.obolibrary.org/obo/MP_0005370
# 3  http://purl.obolibrary.org/obo/MP_0000001
# 4  http://purl.obolibrary.org/obo/MP_0005370
#
#                                            property  \
# 0  http://mousephenotype.org/ontology#childTwoLabel
# 1  http://mousephenotype.org/ontology#childTwoLabel
# 2  http://mousephenotype.org/ontology#childTwoLabel
# 3  http://mousephenotype.org/ontology#childTwoLabel
# 4  http://mousephenotype.org/ontology#childTwoLabel
#
#                                       value
# 0  abnormal hepatobiliary system physiology
# 1                 abnormal liver physiology
# 2                 abnormal liver physiology
# 3            abnormal hepatocyte physiology
# 4            abnormal hepatocyte physiology

# %%
#df_mp_c3 = df_mp_c2.copy()
#df_mp_c3.columns = ['sub','phenotype']
#df_mp_c3 = df_mp_c3.merge(right=df_mp_p,left_on='sub', right_on='y', how='inner')
#df_mp_c3=df_mp_c3[['phenotype','x']].drop_duplicates()
#df_mp_c3.columns = ['y','x']
#df_mp_c3.head()

# %%
df=pd.concat([df_mp_l,df_child1_l,df_child1_s,df_child2_s,df_child2_l,dfhs,dfhl])
df.head()
# Out:
#                                    phenotype  \
# 0  http://purl.obolibrary.org/obo/MP_0000001
# 1  http://purl.obolibrary.org/obo/MP_0005370
# 2  http://purl.obolibrary.org/obo/MP_0002139
# 3  http://purl.obolibrary.org/obo/MP_0000609
# 4  http://purl.obolibrary.org/obo/MP_0010080
#
#                                      property  \
# 0  http://www.w3.org/2000/01/rdf-schema#label
# 1  http://www.w3.org/2000/01/rdf-schema#label
# 2  http://www.w3.org/2000/01/rdf-schema#label
# 3  http://www.w3.org/2000/01/rdf-schema#label
# 4  http://www.w3.org/2000/01/rdf-schema#label
#
#                                       value
# 0                       mammalian phenotype
# 1            liver/biliary system phenotype
# 2  abnormal hepatobiliary system physiology
# 3                 abnormal liver physiology
# 4            abnormal hepatocyte physiology

# %%
def curie_replace(x, curie_map):
    y = x
    for prefix in curie_map:
        y = y.replace(curie_map[prefix],prefix+":")
    return y

df.drop_duplicates(inplace = True)
df['phenotype'] = df.apply(lambda row: curie_replace(row['phenotype'], curie_map), axis=1)
df['property'] = df.apply(lambda row: curie_replace(row['property'], curie_map), axis=1)

df.head()
# Out:
#     phenotype    property                                     value
# 0  MP:0000001  rdfs:label                       mammalian phenotype
# 1  MP:0005370  rdfs:label            liver/biliary system phenotype
# 2  MP:0002139  rdfs:label  abnormal hepatobiliary system physiology
# 3  MP:0000609  rdfs:label                 abnormal liver physiology
# 4  MP:0010080  rdfs:label            abnormal hepatocyte physiology

# %%
df['property'].value_counts()
# Out:
# impc:childOneSynonym     217010
# impc:childTwoSynonym     187950
# impc:childOneLabel       111961
# impc:childTwoLabel        95664
# oio:hasExactSynonym       22800
# rdfs:label                12963
# impc:hpExactSynonym        4211
# impc:hpLabel               2023
# oio:hasRelatedSynonym       890
# oio:hasNarrowSynonym        488
# Name: property, dtype: int64

# %%
df.reset_index(inplace=True,drop=True)
df.to_csv("impc_search_index.csv",index=False)

# %%
df[df['phenotype']=='MP:0005266'].to_csv("impc_example_")
# Out:
#          phenotype             property  \
# 8786    MP:0005266           rdfs:label
# 28589   MP:0005266  oio:hasExactSynonym
# 28590   MP:0005266  oio:hasExactSynonym
# 88376   MP:0005266   impc:childOneLabel
# 88383   MP:0005266   impc:childOneLabel
# 88391   MP:0005266   impc:childOneLabel
# 88400   MP:0005266   impc:childOneLabel
# 101505  MP:0005266   impc:childOneLabel
# 101513  MP:0005266   impc:childOneLabel
# 102947  MP:0005266   impc:childOneLabel
# 102953  MP:0005266   impc:childOneLabel
# 102959  MP:0005266   impc:childOneLabel
# 102965  MP:0005266   impc:childOneLabel
# 102971  MP:0005266   impc:childOneLabel
# 102977  MP:0005266   impc:childOneLabel
# 104057  MP:0005266   impc:childOneLabel
# 104063  MP:0005266   impc:childOneLabel
# 104069  MP:0005266   impc:childOneLabel
# 104075  MP:0005266   impc:childOneLabel
# 104081  MP:0005266   impc:childOneLabel
# 104086  MP:0005266   impc:childOneLabel
# 104093  MP:0005266   impc:childOneLabel
# 104100  MP:0005266   impc:childOneLabel
# 104171  MP:0005266   impc:childOneLabel
# 104187  MP:0005266   impc:childOneLabel
# 104193  MP:0005266   impc:childOneLabel
# 118347  MP:0005266   impc:childOneLabel
# 118350  MP:0005266   impc:childOneLabel
# 118354  MP:0005266   impc:childOneLabel
# 118360  MP:0005266   impc:childOneLabel
# ...            ...                  ...
# 624572  MP:0005266   impc:childTwoLabel
# 624576  MP:0005266   impc:childTwoLabel
# 624580  MP:0005266   impc:childTwoLabel
# 624583  MP:0005266   impc:childTwoLabel
# 624587  MP:0005266   impc:childTwoLabel
# 624591  MP:0005266   impc:childTwoLabel
# 624594  MP:0005266   impc:childTwoLabel
# 624598  MP:0005266   impc:childTwoLabel
# 624602  MP:0005266   impc:childTwoLabel
# 624605  MP:0005266   impc:childTwoLabel
# 624609  MP:0005266   impc:childTwoLabel
# 624613  MP:0005266   impc:childTwoLabel
# 624616  MP:0005266   impc:childTwoLabel
# 624620  MP:0005266   impc:childTwoLabel
# 624626  MP:0005266   impc:childTwoLabel
# 624629  MP:0005266   impc:childTwoLabel
# 624633  MP:0005266   impc:childTwoLabel
# 624643  MP:0005266   impc:childTwoLabel
# 624646  MP:0005266   impc:childTwoLabel
# 624649  MP:0005266   impc:childTwoLabel
# 624655  MP:0005266   impc:childTwoLabel
# 624659  MP:0005266   impc:childTwoLabel
# 624663  MP:0005266   impc:childTwoLabel
# 624667  MP:0005266   impc:childTwoLabel
# 624675  MP:0005266   impc:childTwoLabel
# 624678  MP:0005266   impc:childTwoLabel
# 624689  MP:0005266   impc:childTwoLabel
# 649726  MP:0005266  impc:hpExactSynonym
# 649727  MP:0005266  impc:hpExactSynonym
# 653937  MP:0005266         impc:hpLabel
#
#                                                     value
# 8786                                  abnormal metabolism
# 28589                          abnormal metabolic process
# 28590                             metabolic abnormalities
# 88376   decreased mortality induced by ionizing radiation
# 88383    abnormal mortality induced by ionizing radiation
# 88391   increased mortality induced by ionizing radiation
# 88400    increased mortality induced by gamma-irradiation
# 101505                        impaired exercise endurance
# 101513                 decreased aerobic running capacity
# 102947                                 abnormal autophagy
# 102953                                 impaired autophagy
# 102959                                 enhanced autophagy
# 102965                             abnormal reticulophagy
# 102971                                 abnormal mitophagy
# 102977                   abnormal autophagosome formation
# 104057                                abnormal DNA repair
# 104063                           abnormal mismatch repair
# 104069                      abnormal base-excision repair
# 104075            abnormal single-strand DNA break repair
# 104081            abnormal double-strand DNA break repair
# 104086           abnormal cellular cholesterol metabolism
# 104093                       increased cholesterol efflux
# 104100                       decreased cholesterol efflux
# 104171                           abnormal DNA replication
# 104187                               abnormal translation
# 104193                  abnormal translational elongation
# 118347                        abnormal exercise endurance
# 118350                        enhanced exercise endurance
# 118354                 increased aerobic running capacity
# 118360                   abnormal carbohydrate metabolism
# ...                                                   ...
# 624572                 increased creatine kinase activity
# 624576                 decreased creatine kinase activity
# 624580    abnormal phospholipid transfer protein activity
# 624583   increased phospholipid transfer protein activity
# 624587   decreased phospholipid transfer protein activity
# 624591  abnormal glyceraldehyde-3-phosphate dehydrogen...
# 624594  increased glyceraldehyde-3-phosphate dehydroge...
# 624598  decreased glyceraldehyde-3-phosphate dehydroge...
# 624602                  abnormal NAD(P)H oxidase activity
# 624605                 increased NAD(P)H oxidase activity
# 624609                 decreased NAD(P)H oxidase activity
# 624613                  abnormal pyruvate kinase activity
# 624616                 increased pyruvate kinase activity
# 624620                 decreased pyruvate kinase activity
# 624626                               abnormal lipogenesis
# 624629                              decreased lipogenesis
# 624633                              increased lipogenesis
# 624643                    insensitivity to growth hormone
# 624646               insensitivity to parathyroid hormone
# 624649                      abnormal response to vitamins
# 624655                  abnormal acetaminophen metabolism
# 624659                     abnormal fluoxetine metabolism
# 624663                abnormal trichloroethene metabolism
# 624667              abnormal tetrachloroethene metabolism
# 624675                         increased basal metabolism
# 624678                         decreased basal metabolism
# 624689                     abnormal citrulline metabolism
# 649726                             Metabolism abnormality
# 649727                             Laboratory abnormality
# 653937              Abnormality of metabolism/homeostasis
#
# [1881 rows x 3 columns]
